# %% [markdown]
# # Exercise house keeping
#
# - A: U1.195 (me)
# - B: 02.058 (Marco)
# - C: 02.090 (Luca)
# - D: 02.094 (Janos)
# - E: 02.054 (Sasha)
#
# ## Support sessions
# - Mon 9--10 in room 02.058
# - Tue 16:30--17:30 in room 02.058
# - no formal content: you ask questions, we try to help (attempt the exercises ahead of time)
# - strictly optional

# %% [markdown]
# ## Scoring of the exercises
# - We don't grade the exercises, but check for whether you made a 'serious attempt'. We internally assign each sub exercise 0, 0.5, 1.0 points. You need to hand in at least 5 and have at least 7.5 points in total.
# - Exercise don't change a lot from year-to-year and we know there are previous solutions out there. If we detect you copied previous solutions, you get 0 points. Same if it seems the entire solution is from ChatGPT without your input.

# %% [markdown]
# ## Format
# - If you work in groups, please mention you study partners on your exercise.
# - Name your submissions `LASTNAME_FIRSTNAME...`.
# - File formats in order of preference:
#   * `ipynb` notebook
#   * `PDF`
#   * Photos of handwritten solutions are fine. please embed in pdf
#   * Code should be in an executable form (notebook or script file). If you summarize the results in a pdf, please upload the code as well.
#   * No photos of computer screens. Save the file, upload it!

# %% [markdown]
# ## Please don't...
#
# ### Copy latex or code into work
# ![image.png](attachment:b3697a10-f1ec-4e10-982d-866585793ea0.png)
#
# ### submit pictures of computers...
# ![image.png](attachment:dde81ee9-9360-44bd-9bbc-616232292a07.png)

# %% [markdown]
# ## Force generation through polymerization
#
# In contrast to macroscopic objects, the cytoskeleton is never static by constantly turns over.
# I encourage you to watch the excellent [video by Julie Theriot](https://www.youtube.com/watch?v=FIT0fdt6c3Y) on this topic (youtu.be/FIT0fdt6c3Y).
#
# She explains how polymerization of action is the basis of cell motility and has led to fascinating biology such as the "comet-tails" of listeria.

# %% [markdown]
# ### Cytoskeletal filaments are always in flux
#
# * actin and microtubuli are made from monomers
# * filaments are polar
# * polymerization involves hydrolysis of ATP

# %% [markdown]
# ### Actin filaments
#
# ![image.png](figures/actin_polymerisation.png)
# [The Cell: a molecular approach](https://www.ncbi.nlm.nih.gov/books/NBK9908/figure/A1767/?report=objectonly)

# %% [markdown]
# ### Filling the void
#
# ![image.png](figures/listeria_propulsion.png)
#
# by [mechanobio.info](https://www.mechanobio.info/pathogenesis/what-are-actin-comet-tails/).

# %% [markdown]
# ### Thermal fluctuations to force
#
# ![image.png](figures/actin_monomer_addition.png)
#
#  * thermal fluctuations open the space between the membrane and the filament
#  * a new monomer is added (which consumes ATP)
#
# Note that such force generation is **only** possible because the reaction is irreversible and consumes ATP. An equilibrium reaction could not generate a force.
